# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("diabetes_prediction_dataset.csv")
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
df.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        gender    age  hypertension  heart_disease  smoking_history    bmi  \
# 0       False  False         False          False            False  False
# 1       False  False         False          False            False  False
# 2       False  False         False          False            False  False
# 3       False  False         False          False            False  False
# 4       False  False         False          False            False  False
# ...       ...    ...           ...            ...              ...    ...
# 99995   False  False         False          False            False  False
# 99996   False  False         False          False            False  False
# 99997   False  False         False          False            False  False
# 99998   False  False         False          False            False  False
# 99999   False  False         False          False            False  False
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0            False                False     False
# 1            False                False     False
# 2            False                False     False
# 3            False                False     False
# 4            False                False     False
# ...            ...                  ...       ...
# 99995        False                False     False
# 99996        False                False     False
# 99997        False                False     False
# 99998        False                False     False
# 99999        False                False     False
#
# [100000 rows x 9 columns]>

# %%
print(df.columns.values)
# Out:
# ['gender' 'age' 'hypertension' 'heart_disease' 'smoking_history' 'bmi'
#  'HbA1c_level' 'blood_glucose_level' 'diabetes']

# %%
x=df.drop(labels=['gender','smoking_history','diabetes'],axis=1)

# %%
x.head()
# Out:
#     age  hypertension  heart_disease    bmi  HbA1c_level  blood_glucose_level
# 0  80.0             0              1  25.19          6.6                  140
# 1  54.0             0              0  27.32          6.6                   80
# 2  28.0             0              0  27.32          5.7                  158
# 3  36.0             0              0  23.45          5.0                  155
# 4  76.0             1              1  20.14          4.8                  155

# %%
y=df['diabetes']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: diabetes, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
X_train.head()
# Out:
#         age  hypertension  heart_disease    bmi  HbA1c_level  \
# 98980  27.0             0              0  27.32          6.6
# 69824  18.0             0              0  21.87          4.0
# 9928   33.0             0              0  27.32          5.0
# 75599  50.0             0              0  35.49          6.2
# 95621  80.0             0              1  35.40          8.2
#
#        blood_glucose_level
# 98980                  158
# 69824                  200
# 9928                    80
# 75599                   90
# 95621                  155

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(X_test)
print(y_pred)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import accuracy_score
print(f"The accuracy is ",accuracy_score(y_test,y_pred))
# Out:
# The accuracy is  0.96748

# %%
import joblib
joblib.dump(model,"model.pkl")
# Out:
# ['model.pkl']
